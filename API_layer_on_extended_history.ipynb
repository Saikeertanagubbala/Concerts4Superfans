# %%
import spotipy
import os
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=os.getenv('spotify_client_ID'),
    client_secret=os.getenv('spotify_client_secret'),
    redirect_uri="http://127.0.0.1:3000",
    scope="user-top-read"
))

# %%
top_artists_medium = sp.current_user_top_artists(limit=50, time_range="medium_term")
print(top_artists_medium.keys())
# Out:
# dict_keys(['items', 'total', 'limit', 'offset', 'href', 'next', 'previous'])

# %%
top_artists_medium['total']
# Out:
# 97

# %%
top_artists_long = sp.current_user_top_artists(limit=50, offset=50, time_range="long_term")
print(top_artists_long.keys())
# Out:
# dict_keys(['items', 'total', 'limit', 'offset', 'href', 'next', 'previous'])

# %%
top_artists_long['total']
# Out:
# 266

# %%
top_artists_short = sp.current_user_top_artists(limit=50, time_range="short_term")
print(top_artists_short.keys())
# Out:
# dict_keys(['items', 'total', 'limit', 'offset', 'href', 'next', 'previous'])

# %%
top_artists_short['total']
# Out:
# 31

# %%
def get_short_term_top_tracks(sp, limit=50):
    offset = 0
    all_tracks = []

    while True:
        results = sp.current_user_top_tracks(
            limit=50,
            offset=offset,
            time_range="short_term"
        )
        batch = results["items"]
        print("offset =", offset, "count =", len(batch))

        if len(batch) < 50:
            break

        offset += 50

        offset += limit

    return all_tracks
